# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p1 = np.random.randn(10000)

mu, sigma = 0, 1.0
p2 = np.random.normal(mu, sigma, 10000)

# %%
plt.plot(p1);

# %%
plt.hist(p1, bins=20, normed=1);

# %%
plt.hist(p2, bins=20);
