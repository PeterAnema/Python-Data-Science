# %%
import csv

path = r"datasets/European_Red_List_November2017/European_Mammals_Red_List_Nov_2009.csv"

with open(path, 'r') as f:
    
    reader = csv.DictReader(f, delimiter=',', quotechar='"')
    
    print(reader.fieldnames)

    for row in reader:
        print(row['Order'], row['Family'], row['Species'], row['Subspecies'])

    print(data)
# Out:
# ['\ufeffKingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species', 'Subspecies', 'Taxonomic Notes', 'Endemic to Europe', 'Endemic to EU27', 'European regional Red List Category', 'European regional Red List Criteria', 'EU27 regional Red List Category', 'EU27 regional Red List Criteria', 'Rationale of the Red List Category', 'Population Trend', 'Range', 'Population', 'Habitat', 'Threats', 'Conservation Actions', 'Use and Trade', 'Red List Assessors', 'Taxonomic Authority', 'Red List Reviewers', 'Red List Contributors', 'Scientific Name', 'Endemic to EU25', 'EU25 regional Red List Category', 'EU25 regional Red List Criteria', 'Conservation status analysis', 'EU28 regional Red List Category', 'EU28 regional Red List Criteria', 'Endemic to EU28', 'Assessment Date']
# CARNIVORA CANIDAE
# CARNIVORA CANIDAE
# CARNIVORA CANIDAE
# CARNIVORA CANIDAE
# CARNIVORA CANIDAE
# CARNIVORA FELIDAE
# CARNIVORA FELIDAE
# CARNIVORA FELIDAE
# CARNIVORA FELIDAE
# CARNIVORA HERPESTIDAE
# ...
