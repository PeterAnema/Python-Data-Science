# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ### Create 2 numpy arrays and preform some calculations

# %%
a1 = np.array([1,2,3,4,5])
a1
# Out:
# array([1, 2, 3, 4, 5])

# %%
a2 = np.arange(10,15)
a2
# Out:
# array([10, 11, 12, 13, 14])

# %%
a1 + a2
# Out:
# array([11, 13, 15, 17, 19])

# %%
a1 - a2
# Out:
# array([-9, -9, -9, -9, -9])

# %%
a1 * a2
# Out:
# array([10, 22, 36, 52, 70])

# %%
a1 / a2
# Out:
# array([0.1       , 0.18181818, 0.25      , 0.30769231, 0.35714286])

# %%
a1 // a2
# Out:
# array([0, 0, 0, 0, 0])

# %%
a1 % a2
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.add(a1, a2)
# Out:
# array([11, 13, 15, 17, 19])

# %%
np.subtract(a1,a2)
# Out:
# array([-9, -9, -9, -9, -9])

# %%
np.multiply(a1, a2)
# Out:
# array([10, 22, 36, 52, 70])

# %%
np.divide(a1, a2)
# Out:
# array([0.1       , 0.18181818, 0.25      , 0.30769231, 0.35714286])

# %%
np.floor_divide(a1, a2)
# Out:
# array([0, 0, 0, 0, 0])

# %%
np.mod(a1, a2)
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# ### Part 2: Create x and y. And plot

# %%
x = np.linspace(0.1, 10, 1000)

# %%
y = np.sin(x) / x

# %%
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="432">
