# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/Nobel_Prize.csv')
df
# Out:
#      year    category overallMotivation   id  \
# 0    2017     physics               NaN  941
# 1    2017     physics               NaN  942
# 2    2017     physics               NaN  943
# 3    2017   chemistry               NaN  944
# 4    2017   chemistry               NaN  945
# 5    2017   chemistry               NaN  946
# 6    2017    medicine               NaN  938
# 7    2017    medicine               NaN  939
# 8    2017    medicine               NaN  940
# 9    2017  literature               NaN  947
# 10   2017       peace               NaN  948
# 11   2017   economics               NaN  949
# 12   2016     physics               NaN  928
# 13   2016     physics               NaN  929
# 14   2016     physics               NaN  930
# 15   2016   chemistry               NaN  931
# 16   2016   chemistry               NaN  932
# 17   2016   chemistry               NaN  933
# 18   2016    medicine               NaN  927
# 19   2016  literature               NaN  937
# ...

# %%
import os
os.chdir("/")
# !ls
